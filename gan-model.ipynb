# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import time
import os
from skimage.metrics import structural_similarity as ssim
import tensorflow as tf
import sklearn
from sklearn.model_selection import train_test_split

# %%
def citf(image):
    tmp = np.fft.fftshift(cv2.dft(np.float32(image), flags=cv2.DFT_COMPLEX_OUTPUT))
    complex_matrix = tmp[:,:,0] + 1j * tmp[:,:,1]
    return complex_matrix

# %%
def cfti(kspace):
    img_inverse = np.flipud(np.fliplr(np.abs(np.fft.ifft2(kspace))))
    return img_inverse

# %%
def show_both(kspace):
    mag_spe = 20*np.log(np.abs(kspace))
    plt.subplot(121), plt.imshow(cfti(kspace), cmap='gray')
    plt.title('Input Image'), plt.xticks([]), plt.yticks([])
    plt.subplot(122), plt.imshow(mag_spe, cmap='gray')
    plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
    plt.show()

# %%
def diff(t_kspace , u_kspace):
    plt.subplot(121), plt.imshow(cfti(t_kspace), cmap='gray')
    plt.title('Ground Truth'), plt.xticks([]), plt.yticks([])
    plt.subplot(122), plt.imshow(cfti(u_kspace), cmap='gray')
    plt.title('Undersampled Image'), plt.xticks([]), plt.yticks([])
    plt.show()

# %%
images = []
def process_file(file_path):
    if "mask" in file_path or "README" in file_path or ".csv" in file_path:
        time.sleep(0)
    else:
        image = cv2.imread(file_path,0)
        image = np.array(image)
        image = image.astype('float32') / 255.0
        images.append(image)
        return
for folder_name, subfolders, filenames in os.walk("/kaggle/input/lgg-mri-segmentation/kaggle_3m"):
    for filename in filenames:
        if "mask" not in filename:
            file_path = os.path.join(folder_name, filename)
            process_file(file_path)
images = np.asarray(images)

# %%
kspaces = []
for image in images:
    kspace = citf(image)
    kspaces.append(np.array(kspace))
kspaces = np.asarray(kspaces)

# %%
mask = np.zeros((256,256))
mask[112:144,:] = np.ones((32,256))
plt.imshow(mask, cmap='gray')

# %%
def unsample_data(data, mask):
    u_kspaces = []
    u_images = []
    for i in range(kspaces.shape[0]):
        u_kspace = np.multiply(kspaces[i,:,:], mask)
        u_kspaces.append(u_kspace)
        u_images.append(cfti(u_kspace))
    return np.array(u_kspaces) , np.array(u_images)

# %%
u_kspaces , u_images = unsample_data(kspaces,mask)

# %%
np.savez('data.npz',kspaces=kspaces , u_kspaces = u_kspaces , images=images , u_images=u_images)

# %%
import numpy as np
data = np.load('data.npz')
kspaces = data['kspaces']
u_kspaces = data['u_kspaces']
images = data['images']
u_images = data['u_images']

# %%
show_both(u_kspaces[100,:,:])
# Out:
# /tmp/ipykernel_47/3086757226.py:2: RuntimeWarning: divide by zero encountered in log
#   mag_spe = 20*np.log(np.abs(kspace))

# %%
diff(kspaces[100,:,:],u_kspaces[100,:,:])

# %%
X_train, X_test, Y_train, Y_test = train_test_split(u_images , images , test_size=0.2, random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers

def ssim_loss(y_true, y_pred):
    return 1 - tf.reduce_mean(tf.image.ssim(y_true, y_pred, 1.0))

def res_block(x, filters, kernel_size=3, stride=1, padding='same'):
    """Residual block."""
    res = x
    x = layers.Conv2D(filters, kernel_size, strides=stride, padding=padding, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(filters, kernel_size, strides=stride, padding=padding)(x)
    x = layers.BatchNormalization()(x)
    x = layers.add([x, res])
    x = layers.Activation('relu')(x)
    return x

def ResNet(input_shape, num_residual_blocks):
    """Builds the ResNet."""
    inputs = layers.Input(shape=input_shape)
    x = inputs
    
    # Input Down-sampling
    x = layers.Conv2D(64, (3, 3), strides=2, padding='same', activation='relu')(x)
    x = layers.Conv2D(64, (3, 3), strides=2, padding='same', activation='relu')(x)
    
    # Residual Blocks
    for _ in range(num_residual_blocks):
        x = res_block(x, 64)
    
    # Output Up-sampling
    x = layers.Conv2DTranspose(64, (3, 3), strides=2, padding='same', activation='relu')(x)
    x = layers.Conv2DTranspose(64, (3, 3), strides=2, padding='same', activation='relu')(x)
    
    # Final Convolution Layer
    outputs = layers.Conv2D(1, (7, 7), strides=1, padding='same', activation='sigmoid')(x)
    
    # Define the model
    model = models.Model(inputs, outputs)
    
    # Compile the model
    model.compile(optimizer=optimizers.Adam(learning_rate=0.001),loss=ssim_loss)
    
    return model

# Set input shape and number of residual blocks based on the paper
input_shape = (256,256, 1)  # Assuming grayscale MRI images with variable size
num_residual_blocks = 34

# Create the model
model = ResNet(input_shape, num_residual_blocks)

# Model summary
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 1)]        0         []
#
#  conv2d_71 (Conv2D)          (None, 128, 128, 64)         640       ['input_2[0][0]']
#
#  conv2d_72 (Conv2D)          (None, 64, 64, 64)           36928     ['conv2d_71[0][0]']
#
#  conv2d_73 (Conv2D)          (None, 64, 64, 64)           36928     ['conv2d_72[0][0]']
#
#  batch_normalization_68 (Ba  (None, 64, 64, 64)           256       ['conv2d_73[0][0]']
#  tchNormalization)
#
#  conv2d_74 (Conv2D)          (None, 64, 64, 64)           36928     ['batch_normalization_68[0][0]
#                                                                     ']
#
#  batch_normalization_69 (Ba  (None, 64, 64, 64)           256       ['conv2d_74[0][0]']
#  tchNormalization)
#
#  add_34 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_69[0][0]
#                                                                     ',
#                                                                      'conv2d_72[0][0]']
#
#  activation_34 (Activation)  (None, 64, 64, 64)           0         ['add_34[0][0]']
#
#  conv2d_75 (Conv2D)          (None, 64, 64, 64)           36928     ['activation_34[0][0]']
#
#  batch_normalization_70 (Ba  (None, 64, 64, 64)           256       ['conv2d_75[0][0]']
#  tchNormalization)
#
#  conv2d_76 (Conv2D)          (None, 64, 64, 64)           36928     ['batch_normalization_70[0][0]
#                                                                     ']
#
#  batch_normalization_71 (Ba  (None, 64, 64, 64)           256       ['conv2d_76[0][0]']
#  tchNormalization)
#
#  add_35 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_71[0][0]
#                                                                     ',
#                                                                      'activation_34[0][0]']
#
#  activation_35 (Activation)  (None, 64, 64, 64)           0         ['add_35[0][0]']
#
#  conv2d_77 (Conv2D)          (None, 64, 64, 64)           36928     ['activation_35[0][0]']
#
#  batch_normalization_72 (Ba  (None, 64, 64, 64)           256       ['conv2d_77[0][0]']
#  tchNormalization)
#
#  conv2d_78 (Conv2D)          (None, 64, 64, 64)           36928     ['batch_normalization_72[0][0]
#                                                                     ']
#
#  batch_normalization_73 (Ba  (None, 64, 64, 64)           256       ['conv2d_78[0][0]']
#  tchNormalization)
#
#  add_36 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_73[0][0]
#                                                                     ',
#                                                                      'activation_35[0][0]']
#
#  activation_36 (Activation)  (None, 64, 64, 64)           0         ['add_36[0][0]']
#
#  conv2d_79 (Conv2D)          (None, 64, 64, 64)           36928     ['activation_36[0][0]']
#
#  batch_normalization_74 (Ba  (None, 64, 64, 64)           256       ['conv2d_79[0][0]']
#  tchNormalization)
#
#  conv2d_80 (Conv2D)          (None, 64, 64, 64)           36928     ['batch_normalization_74[0][0]
#                                                                     ']
#
#  batch_normalization_75 (Ba  (None, 64, 64, 64)           256       ['conv2d_80[0][0]']
#  tchNormalization)
#
#  add_37 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_75[0][0]
#                                                                     ',
#                                                                      'activation_36[0][0]']
#
#  activation_37 (Activation)  (None, 64, 64, 64)           0         ['add_37[0][0]']
#
#  conv2d_81 (Conv2D)          (None, 64, 64, 64)           36928     ['activation_37[0][0]']
#
#  batch_normalization_76 (Ba  (None, 64, 64, 64)           256       ['conv2d_81[0][0]']
#  tchNormalization)
#
#  conv2d_82 (Conv2D)          (None, 64, 64, 64)           36928     ['batch_normalization_76[0][0]
#                                                                     ']
#
#  batch_normalization_77 (Ba  (None, 64, 64, 64)           256       ['conv2d_82[0][0]']
#  tchNormalization)
#
#  add_38 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_77[0][0]
#                                                                     ',
#                                                                      'activation_37[0][0]']
#
#  activation_38 (Activation)  (None, 64, 64, 64)           0         ['add_38[0][0]']
#
#  conv2d_83 (Conv2D)          (None, 64, 64, 64)           36928     ['activation_38[0][0]']
#
#  batch_normalization_78 (Ba  (None, 64, 64, 64)           256       ['conv2d_83[0][0]']
#  tchNormalization)
#
#  conv2d_84 (Conv2D)          (None, 64, 64, 64)           36928     ['batch_normalization_78[0][0]
#                                                                     ']
#
#  batch_normalization_79 (Ba  (None, 64, 64, 64)           256       ['conv2d_84[0][0]']
#  tchNormalization)
#
#  add_39 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_79[0][0]
#                                                                     ',
#                                                                      'activation_38[0][0]']
#
#  activation_39 (Activation)  (None, 64, 64, 64)           0         ['add_39[0][0]']
#
#  conv2d_85 (Conv2D)          (None, 64, 64, 64)           36928     ['activation_39[0][0]']
#
#  batch_normalization_80 (Ba  (None, 64, 64, 64)           256       ['conv2d_85[0][0]']
#  tchNormalization)
#
#  conv2d_86 (Conv2D)          (None, 64, 64, 64)           36928     ['batch_normalization_80[0][0]
#                                                                     ']
#
#  batch_normalization_81 (Ba  (None, 64, 64, 64)           256       ['conv2d_86[0][0]']
#  tchNormalization)
#
#  add_40 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_81[0][0]
#                                                                     ',
#                                                                      'activation_39[0][0]']
#
#  activation_40 (Activation)  (None, 64, 64, 64)           0         ['add_40[0][0]']
#
#  conv2d_87 (Conv2D)          (None, 64, 64, 64)           36928     ['activation_40[0][0]']
#
#  batch_normalization_82 (Ba  (None, 64, 64, 64)           256       ['conv2d_87[0][0]']
#  tchNormalization)
#
#  conv2d_88 (Conv2D)          (None, 64, 64, 64)           36928     ['batch_normalization_82[0][0]
#                                                                     ']
#
#  batch_normalization_83 (Ba  (None, 64, 64, 64)           256       ['conv2d_88[0][0]']
#  tchNormalization)
#
#  add_41 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_83[0][0]
#                                                                     ',
#                                                                      'activation_40[0][0]']
#
#  activation_41 (Activation)  (None, 64, 64, 64)           0         ['add_41[0][0]']
#
#  conv2d_89 (Conv2D)          (None, 64, 64, 64)           36928     ['activation_41[0][0]']
#
#  batch_normalization_84 (Ba  (None, 64, 64, 64)           256       ['conv2d_89[0][0]']
#  tchNormalization)
#
#  conv2d_90 (Conv2D)          (None, 64, 64, 64)           36928     ['batch_normalization_84[0][0]
#                                                                     ']
#
#  batch_normalization_85 (Ba  (None, 64, 64, 64)           256       ['conv2d_90[0][0]']
#  tchNormalization)
#
#  add_42 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_85[0][0]
#                                                                     ',
#                                                                      'activation_41[0][0]']
#
#  activation_42 (Activation)  (None, 64, 64, 64)           0         ['add_42[0][0]']
#
#  conv2d_91 (Conv2D)          (None, 64, 64, 64)           36928     ['activation_42[0][0]']
#
#  batch_normalization_86 (Ba  (None, 64, 64, 64)           256       ['conv2d_91[0][0]']
#  tchNormalization)
#
#  conv2d_92 (Conv2D)          (None, 64, 64, 64)           36928     ['batch_normalization_86[0][0]
#                                                                     ']
#
#  batch_normalization_87 (Ba  (None, 64, 64, 64)           256       ['conv2d_92[0][0]']
#  tchNormalization)
#
#  add_43 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_87[0][0]
#                                                                     ',
#                                                                      'activation_42[0][0]']
#
#  activation_43 (Activation)  (None, 64, 64, 64)           0         ['add_43[0][0]']
#
#  conv2d_93 (Conv2D)          (None, 64, 64, 64)           36928     ['activation_43[0][0]']
#
#  batch_normalization_88 (Ba  (None, 64, 64, 64)           256       ['conv2d_93[0][0]']
#  tchNormalization)
#
#  conv2d_94 (Conv2D)          (None, 64, 64, 64)           36928     ['batch_normalization_88[0][0]
#                                                                     ']
#
#  batch_normalization_89 (Ba  (None, 64, 64, 64)           256       ['conv2d_94[0][0]']
#  tchNormalization)
#
#  add_44 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_89[0][0]
#                                                                     ',
#                                                                      'activation_43[0][0]']
#
#  activation_44 (Activation)  (None, 64, 64, 64)           0         ['add_44[0][0]']
#
#  conv2d_95 (Conv2D)          (None, 64, 64, 64)           36928     ['activation_44[0][0]']
#
#  batch_normalization_90 (Ba  (None, 64, 64, 64)           256       ['conv2d_95[0][0]']
#  tchNormalization)
#
#  conv2d_96 (Conv2D)          (None, 64, 64, 64)           36928     ['batch_normalization_90[0][0]
#                                                                     ']
#
#  batch_normalization_91 (Ba  (None, 64, 64, 64)           256       ['conv2d_96[0][0]']
#  tchNormalization)
#
#  add_45 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_91[0][0]
#                                                                     ',
#                                                                      'activation_44[0][0]']
#
#  activation_45 (Activation)  (None, 64, 64, 64)           0         ['add_45[0][0]']
#
#  conv2d_97 (Conv2D)          (None, 64, 64, 64)           36928     ['activation_45[0][0]']
#
#  batch_normalization_92 (Ba  (None, 64, 64, 64)           256       ['conv2d_97[0][0]']
#  tchNormalization)
#
#  conv2d_98 (Conv2D)          (None, 64, 64, 64)           36928     ['batch_normalization_92[0][0]
#                                                                     ']
#
#  batch_normalization_93 (Ba  (None, 64, 64, 64)           256       ['conv2d_98[0][0]']
#  tchNormalization)
#
#  add_46 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_93[0][0]
#                                                                     ',
#                                                                      'activation_45[0][0]']
#
#  activation_46 (Activation)  (None, 64, 64, 64)           0         ['add_46[0][0]']
#
#  conv2d_99 (Conv2D)          (None, 64, 64, 64)           36928     ['activation_46[0][0]']
#
#  batch_normalization_94 (Ba  (None, 64, 64, 64)           256       ['conv2d_99[0][0]']
#  tchNormalization)
#
#  conv2d_100 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_94[0][0]
#                                                                     ']
#
#  batch_normalization_95 (Ba  (None, 64, 64, 64)           256       ['conv2d_100[0][0]']
#  tchNormalization)
#
#  add_47 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_95[0][0]
#                                                                     ',
#                                                                      'activation_46[0][0]']
#
#  activation_47 (Activation)  (None, 64, 64, 64)           0         ['add_47[0][0]']
#
#  conv2d_101 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_47[0][0]']
#
#  batch_normalization_96 (Ba  (None, 64, 64, 64)           256       ['conv2d_101[0][0]']
#  tchNormalization)
#
#  conv2d_102 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_96[0][0]
#                                                                     ']
#
#  batch_normalization_97 (Ba  (None, 64, 64, 64)           256       ['conv2d_102[0][0]']
#  tchNormalization)
#
#  add_48 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_97[0][0]
#                                                                     ',
#                                                                      'activation_47[0][0]']
#
#  activation_48 (Activation)  (None, 64, 64, 64)           0         ['add_48[0][0]']
#
#  conv2d_103 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_48[0][0]']
#
#  batch_normalization_98 (Ba  (None, 64, 64, 64)           256       ['conv2d_103[0][0]']
#  tchNormalization)
#
#  conv2d_104 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_98[0][0]
#                                                                     ']
#
#  batch_normalization_99 (Ba  (None, 64, 64, 64)           256       ['conv2d_104[0][0]']
#  tchNormalization)
#
#  add_49 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_99[0][0]
#                                                                     ',
#                                                                      'activation_48[0][0]']
#
#  activation_49 (Activation)  (None, 64, 64, 64)           0         ['add_49[0][0]']
#
#  conv2d_105 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_49[0][0]']
#
#  batch_normalization_100 (B  (None, 64, 64, 64)           256       ['conv2d_105[0][0]']
#  atchNormalization)
#
#  conv2d_106 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_100[0][0
#                                                                     ]']
#
#  batch_normalization_101 (B  (None, 64, 64, 64)           256       ['conv2d_106[0][0]']
#  atchNormalization)
#
#  add_50 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_101[0][0
#                                                                     ]',
#                                                                      'activation_49[0][0]']
#
#  activation_50 (Activation)  (None, 64, 64, 64)           0         ['add_50[0][0]']
#
#  conv2d_107 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_50[0][0]']
#
#  batch_normalization_102 (B  (None, 64, 64, 64)           256       ['conv2d_107[0][0]']
#  atchNormalization)
#
#  conv2d_108 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_102[0][0
#                                                                     ]']
#
#  batch_normalization_103 (B  (None, 64, 64, 64)           256       ['conv2d_108[0][0]']
#  atchNormalization)
#
#  add_51 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_103[0][0
#                                                                     ]',
#                                                                      'activation_50[0][0]']
#
#  activation_51 (Activation)  (None, 64, 64, 64)           0         ['add_51[0][0]']
#
#  conv2d_109 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_51[0][0]']
#
#  batch_normalization_104 (B  (None, 64, 64, 64)           256       ['conv2d_109[0][0]']
#  atchNormalization)
#
#  conv2d_110 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_104[0][0
#                                                                     ]']
#
#  batch_normalization_105 (B  (None, 64, 64, 64)           256       ['conv2d_110[0][0]']
#  atchNormalization)
#
#  add_52 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_105[0][0
#                                                                     ]',
#                                                                      'activation_51[0][0]']
#
#  activation_52 (Activation)  (None, 64, 64, 64)           0         ['add_52[0][0]']
#
#  conv2d_111 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_52[0][0]']
#
#  batch_normalization_106 (B  (None, 64, 64, 64)           256       ['conv2d_111[0][0]']
#  atchNormalization)
#
#  conv2d_112 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_106[0][0
#                                                                     ]']
#
#  batch_normalization_107 (B  (None, 64, 64, 64)           256       ['conv2d_112[0][0]']
#  atchNormalization)
#
#  add_53 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_107[0][0
#                                                                     ]',
#                                                                      'activation_52[0][0]']
#
#  activation_53 (Activation)  (None, 64, 64, 64)           0         ['add_53[0][0]']
#
#  conv2d_113 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_53[0][0]']
#
#  batch_normalization_108 (B  (None, 64, 64, 64)           256       ['conv2d_113[0][0]']
#  atchNormalization)
#
#  conv2d_114 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_108[0][0
#                                                                     ]']
#
#  batch_normalization_109 (B  (None, 64, 64, 64)           256       ['conv2d_114[0][0]']
#  atchNormalization)
#
#  add_54 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_109[0][0
#                                                                     ]',
#                                                                      'activation_53[0][0]']
#
#  activation_54 (Activation)  (None, 64, 64, 64)           0         ['add_54[0][0]']
#
#  conv2d_115 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_54[0][0]']
#
#  batch_normalization_110 (B  (None, 64, 64, 64)           256       ['conv2d_115[0][0]']
#  atchNormalization)
#
#  conv2d_116 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_110[0][0
#                                                                     ]']
#
#  batch_normalization_111 (B  (None, 64, 64, 64)           256       ['conv2d_116[0][0]']
#  atchNormalization)
#
#  add_55 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_111[0][0
#                                                                     ]',
#                                                                      'activation_54[0][0]']
#
#  activation_55 (Activation)  (None, 64, 64, 64)           0         ['add_55[0][0]']
#
#  conv2d_117 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_55[0][0]']
#
#  batch_normalization_112 (B  (None, 64, 64, 64)           256       ['conv2d_117[0][0]']
#  atchNormalization)
#
#  conv2d_118 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_112[0][0
#                                                                     ]']
#
#  batch_normalization_113 (B  (None, 64, 64, 64)           256       ['conv2d_118[0][0]']
#  atchNormalization)
#
#  add_56 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_113[0][0
#                                                                     ]',
#                                                                      'activation_55[0][0]']
#
#  activation_56 (Activation)  (None, 64, 64, 64)           0         ['add_56[0][0]']
#
#  conv2d_119 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_56[0][0]']
#
#  batch_normalization_114 (B  (None, 64, 64, 64)           256       ['conv2d_119[0][0]']
#  atchNormalization)
#
#  conv2d_120 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_114[0][0
#                                                                     ]']
#
#  batch_normalization_115 (B  (None, 64, 64, 64)           256       ['conv2d_120[0][0]']
#  atchNormalization)
#
#  add_57 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_115[0][0
#                                                                     ]',
#                                                                      'activation_56[0][0]']
#
#  activation_57 (Activation)  (None, 64, 64, 64)           0         ['add_57[0][0]']
#
#  conv2d_121 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_57[0][0]']
#
#  batch_normalization_116 (B  (None, 64, 64, 64)           256       ['conv2d_121[0][0]']
#  atchNormalization)
#
#  conv2d_122 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_116[0][0
#                                                                     ]']
#
#  batch_normalization_117 (B  (None, 64, 64, 64)           256       ['conv2d_122[0][0]']
#  atchNormalization)
#
#  add_58 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_117[0][0
#                                                                     ]',
#                                                                      'activation_57[0][0]']
#
#  activation_58 (Activation)  (None, 64, 64, 64)           0         ['add_58[0][0]']
#
#  conv2d_123 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_58[0][0]']
#
#  batch_normalization_118 (B  (None, 64, 64, 64)           256       ['conv2d_123[0][0]']
#  atchNormalization)
#
#  conv2d_124 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_118[0][0
#                                                                     ]']
#
#  batch_normalization_119 (B  (None, 64, 64, 64)           256       ['conv2d_124[0][0]']
#  atchNormalization)
#
#  add_59 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_119[0][0
#                                                                     ]',
#                                                                      'activation_58[0][0]']
#
#  activation_59 (Activation)  (None, 64, 64, 64)           0         ['add_59[0][0]']
#
#  conv2d_125 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_59[0][0]']
#
#  batch_normalization_120 (B  (None, 64, 64, 64)           256       ['conv2d_125[0][0]']
#  atchNormalization)
#
#  conv2d_126 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_120[0][0
#                                                                     ]']
#
#  batch_normalization_121 (B  (None, 64, 64, 64)           256       ['conv2d_126[0][0]']
#  atchNormalization)
#
#  add_60 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_121[0][0
#                                                                     ]',
#                                                                      'activation_59[0][0]']
#
#  activation_60 (Activation)  (None, 64, 64, 64)           0         ['add_60[0][0]']
#
#  conv2d_127 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_60[0][0]']
#
#  batch_normalization_122 (B  (None, 64, 64, 64)           256       ['conv2d_127[0][0]']
#  atchNormalization)
#
#  conv2d_128 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_122[0][0
#                                                                     ]']
#
#  batch_normalization_123 (B  (None, 64, 64, 64)           256       ['conv2d_128[0][0]']
#  atchNormalization)
#
#  add_61 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_123[0][0
#                                                                     ]',
#                                                                      'activation_60[0][0]']
#
#  activation_61 (Activation)  (None, 64, 64, 64)           0         ['add_61[0][0]']
#
#  conv2d_129 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_61[0][0]']
#
#  batch_normalization_124 (B  (None, 64, 64, 64)           256       ['conv2d_129[0][0]']
#  atchNormalization)
#
#  conv2d_130 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_124[0][0
#                                                                     ]']
#
#  batch_normalization_125 (B  (None, 64, 64, 64)           256       ['conv2d_130[0][0]']
#  atchNormalization)
#
#  add_62 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_125[0][0
#                                                                     ]',
#                                                                      'activation_61[0][0]']
#
#  activation_62 (Activation)  (None, 64, 64, 64)           0         ['add_62[0][0]']
#
#  conv2d_131 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_62[0][0]']
#
#  batch_normalization_126 (B  (None, 64, 64, 64)           256       ['conv2d_131[0][0]']
#  atchNormalization)
#
#  conv2d_132 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_126[0][0
#                                                                     ]']
#
#  batch_normalization_127 (B  (None, 64, 64, 64)           256       ['conv2d_132[0][0]']
#  atchNormalization)
#
#  add_63 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_127[0][0
#                                                                     ]',
#                                                                      'activation_62[0][0]']
#
#  activation_63 (Activation)  (None, 64, 64, 64)           0         ['add_63[0][0]']
#
#  conv2d_133 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_63[0][0]']
#
#  batch_normalization_128 (B  (None, 64, 64, 64)           256       ['conv2d_133[0][0]']
#  atchNormalization)
#
#  conv2d_134 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_128[0][0
#                                                                     ]']
#
#  batch_normalization_129 (B  (None, 64, 64, 64)           256       ['conv2d_134[0][0]']
#  atchNormalization)
#
#  add_64 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_129[0][0
#                                                                     ]',
#                                                                      'activation_63[0][0]']
#
#  activation_64 (Activation)  (None, 64, 64, 64)           0         ['add_64[0][0]']
#
#  conv2d_135 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_64[0][0]']
#
#  batch_normalization_130 (B  (None, 64, 64, 64)           256       ['conv2d_135[0][0]']
#  atchNormalization)
#
#  conv2d_136 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_130[0][0
#                                                                     ]']
#
#  batch_normalization_131 (B  (None, 64, 64, 64)           256       ['conv2d_136[0][0]']
#  atchNormalization)
#
#  add_65 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_131[0][0
#                                                                     ]',
#                                                                      'activation_64[0][0]']
#
#  activation_65 (Activation)  (None, 64, 64, 64)           0         ['add_65[0][0]']
#
#  conv2d_137 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_65[0][0]']
#
#  batch_normalization_132 (B  (None, 64, 64, 64)           256       ['conv2d_137[0][0]']
#  atchNormalization)
#
#  conv2d_138 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_132[0][0
#                                                                     ]']
#
#  batch_normalization_133 (B  (None, 64, 64, 64)           256       ['conv2d_138[0][0]']
#  atchNormalization)
#
#  add_66 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_133[0][0
#                                                                     ]',
#                                                                      'activation_65[0][0]']
#
#  activation_66 (Activation)  (None, 64, 64, 64)           0         ['add_66[0][0]']
#
#  conv2d_139 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_66[0][0]']
#
#  batch_normalization_134 (B  (None, 64, 64, 64)           256       ['conv2d_139[0][0]']
#  atchNormalization)
#
#  conv2d_140 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_134[0][0
#                                                                     ]']
#
#  batch_normalization_135 (B  (None, 64, 64, 64)           256       ['conv2d_140[0][0]']
#  atchNormalization)
#
#  add_67 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_135[0][0
#                                                                     ]',
#                                                                      'activation_66[0][0]']
#
#  activation_67 (Activation)  (None, 64, 64, 64)           0         ['add_67[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 64)         36928     ['activation_67[0][0]']
#  Transpose)
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 64)         36928     ['conv2d_transpose_2[0][0]']
#  Transpose)
#
#  conv2d_141 (Conv2D)         (None, 256, 256, 1)          3137      ['conv2d_transpose_3[0][0]']
#
# ==================================================================================================
# Total params: 2643073 (10.08 MB)
# Trainable params: 2634369 (10.05 MB)
# Non-trainable params: 8704 (34.00 KB)
# __________________________________________________________________________________________________

# %%
model.fit(X_train,Y_train, validation_split=0.2, epochs=25)
# Out:
# Epoch 1/25
# 79/79 [==============================] - 102s 566ms/step - loss: 0.4448 - val_loss: 0.8377
# Epoch 2/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0842 - val_loss: 0.7025
# Epoch 3/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0699 - val_loss: 0.5235
# Epoch 4/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0665 - val_loss: 0.3817
# Epoch 5/25
# 79/79 [==============================] - 39s 494ms/step - loss: 0.0583 - val_loss: 0.1807
# Epoch 6/25
# 79/79 [==============================] - 39s 494ms/step - loss: 0.0582 - val_loss: 0.1209
# Epoch 7/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0611 - val_loss: 0.0825
# Epoch 8/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0540 - val_loss: 0.0841
# Epoch 9/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0545 - val_loss: 0.1070
# Epoch 10/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0541 - val_loss: 0.0657
# Epoch 11/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0508 - val_loss: 0.0831
# Epoch 12/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0485 - val_loss: 0.0757
# Epoch 13/25
# 79/79 [==============================] - 39s 494ms/step - loss: 0.0477 - val_loss: 0.0450
# Epoch 14/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0443 - val_loss: 0.0491
# Epoch 15/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0463 - val_loss: 0.0734
# Epoch 16/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0484 - val_loss: 0.0601
# Epoch 17/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0443 - val_loss: 0.0474
# Epoch 18/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0446 - val_loss: 0.0545
# Epoch 19/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0481 - val_loss: 0.0527
# Epoch 20/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0434 - val_loss: 0.0515
# Epoch 21/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0413 - val_loss: 0.0382
# Epoch 22/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0452 - val_loss: 0.0898
# Epoch 23/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0478 - val_loss: 0.0510
# Epoch 24/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0452 - val_loss: 0.1196
# Epoch 25/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0404 - val_loss: 0.1261

# %%
model.save_weights('model25.h5')

# %%
a = model.history.history['val_loss']
b = model.history.history['loss']
print(a)
print(b)
# Out:
# [0.8377222418785095, 0.7025015354156494, 0.5235400795936584, 0.3817085325717926, 0.18067729473114014, 0.12090986967086792, 0.08248874545097351, 0.08412417024374008, 0.10698600858449936, 0.06567142903804779, 0.0830569788813591, 0.07566861063241959, 0.045024678111076355, 0.04913767799735069, 0.07338526844978333, 0.06007950007915497, 0.0474189817905426, 0.054483912885189056, 0.05267537757754326, 0.05150337889790535, 0.03817252442240715, 0.08981352299451828, 0.05096518620848656, 0.119576096534729, 0.12611888349056244]
# [0.44478994607925415, 0.08416283130645752, 0.06992226839065552, 0.06646914035081863, 0.05830670893192291, 0.0582110732793808, 0.06106797233223915, 0.0540333017706871, 0.05448926240205765, 0.05411915108561516, 0.05077102407813072, 0.048469673842191696, 0.047682151198387146, 0.04428866505622864, 0.04630712419748306, 0.048371512442827225, 0.04428141564130783, 0.04462258145213127, 0.048076026141643524, 0.043350763618946075, 0.041326940059661865, 0.04518658667802811, 0.04775369539856911, 0.04517745226621628, 0.04041117802262306]

# %%
plt.plot(b , label="Training loss")
plt.plot(a , label="Validation loss")
plt.legend()
plt.show()

# %%
model.load_weights('model25.h5')

# %%
output_images = model.predict(X_test)
# Out:
# 25/25 [==============================] - 4s 114ms/step

# %%
# Finding the inverse of mask
inv_mask = np.ones((256,256))
inv_mask[112:144,:] = np.zeros((32,256))
plt.imshow(inv_mask,cmap='gray')

# %%
recon_kspaces = []
recon_images = []
for i in range(len(output_images)):
    r_kspace = np.array(citf(output_images[i]))
    r_kspace = np.multiply(r_kspace , inv_mask)
    r_kspace = r_kspace + citf(X_test[i])
    recon_kspaces.append(r_kspace)
    recon_images.append(cfti(r_kspace))
recon_kspaces = np.asarray(recon_kspaces)
recon_images = np.asarray(recon_images)

# %%
plt.subplot(131), plt.imshow(Y_test[2], cmap='gray')
plt.title('Ground Truth'), plt.xticks([]), plt.yticks([])
plt.subplot(132), plt.imshow(X_test[2], cmap='gray')
plt.title('Undersampled Image'), plt.xticks([]), plt.yticks([])
plt.subplot(133), plt.imshow(recon_images[2], cmap='gray')
plt.title('Reconstructed Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import numpy as np 
import glob
import nibabel as nib 
import os
import pickle 
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from skimage import measure
from skimage.metrics import peak_signal_noise_ratio, structural_similarity

import tensorflow as tf 
from tensorflow.keras.models import Model 
from tensorflow.keras import Input
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import Flatten, Add 
from tensorflow.keras.layers import Concatenate, Activation 
from tensorflow.keras.layers import LeakyReLU, BatchNormalization, Lambda
from tensorflow.keras import backend as K
from tensorflow.keras.initializers import RandomNormal 
# from keras.initializers import RandomNormal
# from tensorflow.python.keras.utils import multi_gpu_model

# %%
# loss for dicriminator 

def accw(y_true, y_pred):
    y_pred = K.clip(y_pred, -1 , 1)
    
    return K.mean (K.equal(y_true, K.round(y_pred)))


def mssim(y_true, y_pred):
    costs = 1.0 -tf.reduce_mean(tf.image.ssim(y_true,y_pred, 2.0))
    
    return costs 

def wloss(y_true, y_predict):
    
    return -K.mean(y_true+y_predict)

# %%
def discriminator(inp_shape = (256,256,1), trainable = True):
    gamma_init = RandomNormal(1. , 0.02)
    
    inp = Input(shape =(256,256,1))
    
    l0 = Conv2D(64, (4,4), strides = (2,2), padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(inp)
    l0 = LeakyReLU(alpha=0.2)(l0)
    
    l1 = Conv2D(64*2, (4,4), strides = (2,2), padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(l0)
    l1 = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(l1)
    l1 = LeakyReLU(alpha=0.2)(l1)
    
    l2 = Conv2D(64*2, (4,4), strides = (2,2), padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(l1)
    l2 = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(l2)
    l2 = LeakyReLU(alpha=0.2)(l2)
    
    l3 = Conv2D(64*8, (4,4), strides = (2,2), padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(l2)
    l3 = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(l3)
    l3 = LeakyReLU(alpha=0.2)(l3)
    
    l4 = Conv2D(64*16, (4,4), strides = (2,2), padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(l3)
    l4 = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(l4)
    l4 = LeakyReLU(alpha=0.2)(l4)
    
    l5 = Conv2D(64*32, (4,4), strides = (2,2), padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(l4)
    l5 = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(l5)
    l5 = LeakyReLU(alpha=0.2)(l5)
    
    l6 = Conv2D(64*16, (4,4), strides = (2,2), padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(l5)
    l6 = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(l6)
    l6 = LeakyReLU(alpha=0.2)(l6)
    
    l7 = Conv2D(64*8, (4,4), strides = (2,2), padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(l6)
    l7 = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(l7)
    l7 = LeakyReLU(alpha=0.2)(l7)
    
    l8 = Conv2D(64*2, (4,4), strides = (2,2), padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(l7)
    l8 = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(l8)
    l8 = LeakyReLU(alpha=0.2)(l8)
    
    l9 = Conv2D(64*2, (4,4), strides = (2,2), padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(l8)
    l9 = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(l9)
    l9 = LeakyReLU(alpha=0.2)(l9)
    
    l10 = Conv2D(64*8, (4,4), strides = (2,2), padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(l9)
    l10 = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(l10)
    l10 = LeakyReLU(alpha=0.2)(l10)
    
    l11 = Add()([l7,l10])
    l11 = LeakyReLU(alpha = 0.2)(l11)
    
    out =  Conv2D(filters = 1, kernel_size = 3, strides = 1, padding= 'same',use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(l11)
    model = Model(inputs = inp, outputs = out )
    return model

# %%
def resden(x,fil,gr,beta, gamma_init, trainable):
    
    x1 = Conv2D(filters=gr, kernel_size=3, strides = 1, padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(x)
    x1 = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(x1)
    x1 = LeakyReLU(alpha=0.2)(x1)
    
    x1 = Concatenate(axis = -1 )([x,x1])
    
    x2 = Conv2D(filters=gr, kernel_size=3, strides = 1, padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(x1)
    x2 = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(x2)
    x2 = LeakyReLU(alpha=0.2)(x2)
    
    x2 = Concatenate(axis = -1 )([x1,x2])
    
    x3 = Conv2D(filters=gr, kernel_size=3, strides = 1, padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(x2)
    x3 = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(x3)
    x3 = LeakyReLU(alpha=0.2)(x3)

    x3 = Concatenate(axis = -1 )([x2,x3])
    
    x4 = Conv2D(filters=gr, kernel_size=3, strides = 1, padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(x3)
    x4 = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(x4)
    x4 = LeakyReLU(alpha=0.2)(x4)
    
    x4 = Concatenate(axis = -1 )([x3,x4])
    
    x5 = Conv2D(filters=fil, kernel_size=3, strides = 1, padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(x4)
    x5 = Lambda(lambda x:x-beta)(x5)
    xout = Add()([x5,x])
    
    return xout

# %%
def resresden(x,fil,gr,betad, betar, gamma_init, trainable):
    
    x1=resden(x,fil,gr,betad,gamma_init,trainable)
    x2=resden(x1,fil,gr,betad,gamma_init,trainable)
    x3=resden(x2,fil,gr,betad,gamma_init,trainable)
    x3=Lambda(lambda x:x-betar)(x3)
    xout = Add()([x3,x])
    
    return xout

# %%
def generator(inp_shape, trainable = True):
    
    gamma_init = RandomNormal(1.,0.02)
    
    fd =512
    gr =32
    nb =12
    betad =0.2
    betar =0.2
    
    inp_real_imag = Input(inp_shape)
    lay_128dn =  Conv2D(64, (4,4), strides = (2,2), padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(inp_real_imag)
    lay_128dn = LeakyReLU(alpha=0.2)(lay_128dn)
    print("lay_128dn",lay_128dn.shape)
    
    lay_64dn =  Conv2D(128, (4,4), strides = (2,2), padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(lay_128dn)
    lay_64dn = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(lay_64dn)
    lay_64dn = LeakyReLU(alpha=0.2)(lay_64dn)
    print("lay_64dn",lay_64dn.shape)
    
    lay_32dn =  Conv2D(256, (4,4), strides = (2,2), padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(lay_64dn)
    lay_32dn = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(lay_32dn)
    lay_32dn = LeakyReLU(alpha=0.2)(lay_32dn)
    print("lay_32dn",lay_32dn.shape)
    
    lay_16dn =  Conv2D(512, (4,4), strides = (2,2), padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(lay_32dn)
    lay_16dn = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(lay_16dn)
    lay_16dn = LeakyReLU(alpha=0.2)(lay_16dn)
    print("lay_16dn",lay_16dn.shape)
    
    lay_8dn =  Conv2D(512, (4,4), strides = (2,2), padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(lay_16dn)
    lay_8dn = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(lay_8dn)
    lay_8dn = LeakyReLU(alpha=0.2)(lay_8dn)
    print("lay_8dn",lay_8dn.shape)
    
    xc1 =  Conv2D(filters=fd,kernel_size=3, strides = 1, padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(lay_8dn)
    xrrd=xc1
    
    
    for m in range(nb):
        xrrd =  resresden(xrrd,fd,gr,betad, betar, gamma_init, trainable)
    
    xc2 = Conv2D(filters=fd,kernel_size=3, strides = 1, padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(xrrd)
    lay_8upc = Add()([xc1,xc2])
    
    lay_16up = Conv2DTranspose(1024, (4,4), strides = (2,2), padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(lay_8upc)
    lay_16up = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(lay_16up)
    lay_16up = Activation('relu')(lay_16up)
    print("lay_16up",lay_16up.shape)
    
    lay_16upc = Concatenate(axis = -1)([lay_16up, lay_16dn])
    print(lay_16upc.shape)
    
    lay_32up =  Conv2DTranspose(256, (4,4), strides = (2,2), padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(lay_16upc)
    lay_32up = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(lay_32up)
    lay_32up = Activation('relu')(lay_32up)
    print("lay_32up",lay_32up.shape)
    
    lay_32upc = Concatenate(axis = -1)([lay_32up, lay_32dn])
    
    lay_64up =  Conv2DTranspose(128, (4,4), strides = (2,2), padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(lay_32upc)
    lay_64up = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(lay_64up)
    lay_64up = Activation('relu')(lay_64up)
    print("lay_64up",lay_64up.shape)
    
    lay_64upc = Concatenate(axis = -1)([lay_64up, lay_64dn])
    
    
    lay_128up =  Conv2DTranspose(64, (4,4), strides = (2,2), padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(lay_64upc)
    lay_128up = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(lay_128up)
    lay_128up = Activation('relu')(lay_128up)
    print("lay_128up",lay_128up.shape)
    
    lay_128upc = Concatenate(axis = -1)([lay_128up, lay_128dn])
    
    lay_256up =  Conv2DTranspose(64, (4,4), strides = (2,2), padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(lay_128upc)
    lay_256up = BatchNormalization(gamma_initializer = gamma_init, trainable = trainable)(lay_256up)
    lay_256up = Activation('relu')(lay_256up)
    print("lay_256up",lay_256up.shape)
    
    out = Conv2D(1, (1,1),strides =(1,1), activation = 'tanh', padding ='same', use_bias = True, kernel_initializer ='he_normal', bias_initializer = 'zeros')(lay_256up)
    
    model = Model(inputs =inp_real_imag, outputs = out )
    
    return model

# %%
def define_gan_model(gen_model, dis_model, inp_shape):
    
    dis_model.trainable = False
    inp =Input(shape = inp_shape)
    out_g = gen_model(inp)
    
    out_dis = dis_model(out_g)
    
    out_g1 = out_g
    
    model = Model(inputs = inp, outputs =[out_dis, out_g, out_g1])
    
    model.summary()
    
    return model

# %%
def train(g_par, d_par, gan_model, dataset_real, u_sampled_data, n_epochs, n_batch, n_critic, clip_val, n_patch, f):
    
    bat_per_epo = int(dataset_real.shape[0] / n_batch)
    half_batch = int(n_batch / 2)
    
    for i in range(n_epochs):
        print('Epochs', i)
        
        for j in range(bat_per_epo):
            
            print('Batch', j)
            
            for k in range(n_critic):
                ix = np.random.randint(0, dataset_real.shape[0], half_batch)
                
                X_real = dataset_real[ix]
                y_real = np.ones((half_batch, n_patch, n_patch, 1))
                
                ix_1 = np.random.randint(0, u_sampled_data.shape[0], half_batch)
                X_fake = g_par.predict(u_sampled_data[ix_1])
                y_fake = -np.ones((half_batch, n_patch, n_patch, 1))
                
                X, y = np.vstack((X_real, X_fake)), np.vstack((y_real, y_fake))
                
                d_loss, accuracy = d_par.train_on_batch(X, y)
                
                for L in d_par.layers:
                    weights = L.get_weights()
                    weights = [np.clip(w, clip_val, clip_val) for w in weights]
                    L.set_weights(weights)
                    
            ix = np.random.randint(0, dataset_real.shape[0], n_batch)

            X_r = dataset_real[ix]
            
            X_gen_inp = u_sampled_data[ix]
            y_gan = np.ones((n_batch, n_patch, n_patch, 1))
            
            g_loss = gan_model.train_on_batch([X_gen_inp], [y_gan, X_r, X_r])
            
            f.write('>%d, %d/%d, d = %.3f, acc = %.3f, w = %.3f, mae = %.3f, mssim = %.3f, g = %.3f  ' % (i+1, j+1, bat_per_epo, d_loss, accuracy, g_loss[1], g_loss[2], g_loss[3]))
            f.write('\n')
            print('>%d, %d/%d, d = %.3f, acc = %.3f, g = %.3f' % (i+1, j+1, bat_per_epo, d_loss, accuracy, g_loss[0]))
            
        filename = 'gen_weight/gen_weights_a5_04d.h5' % (i+1)
        g_par.save_weights(filename)
        
    f.close()

# %%
# data_path = 'preprocessed_data/training.pickle'
# usam_path = 'preprocessed_data/training_usamp.pickle'

# dataset_real = pickle.load(open(data_path,'rb'))

# u_sampled_data = pickle.load(open(usam_path,'rb'))
                             
# dataset_real = np.expand_dims(dataset_real, axis = -1)

# u_sampled_data = np.expand_dims(u_sampled_data, axis = -1)
                             
# u_sampled_data_2c = np.concatenate((u_sampled_data.real, u_sampled_data.imag), axis = -1)
                             
# print(dataset_real.shape)

dataset_real = X_train 
print(dataset_real.shape)
# Out:
# (3143, 256, 256)

# %%
n_epochs = 300
n_batch = 32
n_critic = 3

clip_val =0.05
in_shape_gen = (256,256,2)
in_shape_dis = (256,256,1)
accel = 3

d_model = discriminator(inp_shape = in_shape_dis, trainable =True)

d_model.summary()

d_par = d_model
opt = Adam(lr = 0.0002, beta_1 =0.5)
d_par.compile(loss = wloss, optimizer = opt, metrics = [accw])

g_model = generator(inp_shape =in_shape_gen, trainable = True)

g_par =g_model
g_par.summary()

gan_model = define_gan_model(g_par, d_par, in_shape_gen)

opt1 = Adam(lr =0.0001 , beta_1 = 0.5)

gan_model.compile(loss =[wloss, 'mae', mssim], optimizer = opt1, loss_weights = [0.01, 20.0, 1.0])
n_patch = d_model.output_shape[1]

f = open('./log_a5.txt' , 'a')
train(g_par, d_par, gan_model, dataset_real, u_sampled_data_2c, n_epochs, n_batch, n_critic, clip_val, n_patch, f)
# Out:
# Model: "model_20"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_39 (InputLayer)       [(None, 256, 256, 1)]        0         []
#
#  conv2d_1992 (Conv2D)        (None, 128, 128, 64)         1088      ['input_39[0][0]']
#
#  leaky_re_lu_1634 (LeakyReL  (None, 128, 128, 64)         0         ['conv2d_1992[0][0]']
#  U)
#
#  conv2d_1993 (Conv2D)        (None, 64, 64, 128)          131200    ['leaky_re_lu_1634[0][0]']
#
#  batch_normalization_1597 (  (None, 64, 64, 128)          512       ['conv2d_1993[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1635 (LeakyReL  (None, 64, 64, 128)          0         ['batch_normalization_1597[0][
#  U)                                                                 0]']
#
#  conv2d_1994 (Conv2D)        (None, 32, 32, 128)          262272    ['leaky_re_lu_1635[0][0]']
#
#  batch_normalization_1598 (  (None, 32, 32, 128)          512       ['conv2d_1994[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1636 (LeakyReL  (None, 32, 32, 128)          0         ['batch_normalization_1598[0][
#  U)                                                                 0]']
#
#  conv2d_1995 (Conv2D)        (None, 16, 16, 512)          1049088   ['leaky_re_lu_1636[0][0]']
#
#  batch_normalization_1599 (  (None, 16, 16, 512)          2048      ['conv2d_1995[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1637 (LeakyReL  (None, 16, 16, 512)          0         ['batch_normalization_1599[0][
#  U)                                                                 0]']
#
#  conv2d_1996 (Conv2D)        (None, 8, 8, 1024)           8389632   ['leaky_re_lu_1637[0][0]']
#
#  batch_normalization_1600 (  (None, 8, 8, 1024)           4096      ['conv2d_1996[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1638 (LeakyReL  (None, 8, 8, 1024)           0         ['batch_normalization_1600[0][
#  U)                                                                 0]']
#
#  conv2d_1997 (Conv2D)        (None, 4, 4, 2048)           3355648   ['leaky_re_lu_1638[0][0]']
#                                                           0
#
#  batch_normalization_1601 (  (None, 4, 4, 2048)           8192      ['conv2d_1997[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1639 (LeakyReL  (None, 4, 4, 2048)           0         ['batch_normalization_1601[0][
#  U)                                                                 0]']
#
#  conv2d_1998 (Conv2D)        (None, 2, 2, 1024)           3355545   ['leaky_re_lu_1639[0][0]']
#                                                           6
#
#  batch_normalization_1602 (  (None, 2, 2, 1024)           4096      ['conv2d_1998[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1640 (LeakyReL  (None, 2, 2, 1024)           0         ['batch_normalization_1602[0][
#  U)                                                                 0]']
#
#  conv2d_1999 (Conv2D)        (None, 1, 1, 512)            8389120   ['leaky_re_lu_1640[0][0]']
#
#  batch_normalization_1603 (  (None, 1, 1, 512)            2048      ['conv2d_1999[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1641 (LeakyReL  (None, 1, 1, 512)            0         ['batch_normalization_1603[0][
#  U)                                                                 0]']
#
#  conv2d_2000 (Conv2D)        (None, 1, 1, 128)            1048704   ['leaky_re_lu_1641[0][0]']
#
#  batch_normalization_1604 (  (None, 1, 1, 128)            512       ['conv2d_2000[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1642 (LeakyReL  (None, 1, 1, 128)            0         ['batch_normalization_1604[0][
#  U)                                                                 0]']
#
#  conv2d_2001 (Conv2D)        (None, 1, 1, 128)            262272    ['leaky_re_lu_1642[0][0]']
#
#  batch_normalization_1605 (  (None, 1, 1, 128)            512       ['conv2d_2001[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1643 (LeakyReL  (None, 1, 1, 128)            0         ['batch_normalization_1605[0][
#  U)                                                                 0]']
#
#  conv2d_2002 (Conv2D)        (None, 1, 1, 512)            1049088   ['leaky_re_lu_1643[0][0]']
#
#  batch_normalization_1606 (  (None, 1, 1, 512)            2048      ['conv2d_2002[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1644 (LeakyReL  (None, 1, 1, 512)            0         ['batch_normalization_1606[0][
#  U)                                                                 0]']
#
#  add_463 (Add)               (None, 1, 1, 512)            0         ['leaky_re_lu_1641[0][0]',
#                                                                      'leaky_re_lu_1644[0][0]']
#
#  leaky_re_lu_1645 (LeakyReL  (None, 1, 1, 512)            0         ['add_463[0][0]']
#  U)
#
#  conv2d_2003 (Conv2D)        (None, 1, 1, 1)              4609      ['leaky_re_lu_1645[0][0]']
#
# ==================================================================================================
# Total params: 87723585 (334.64 MB)
# Trainable params: 87711297 (334.59 MB)
# Non-trainable params: 12288 (48.00 KB)
# __________________________________________________________________________________________________
# lay_128dn (None, 128, 128, 64)
# lay_64dn (None, 64, 64, 128)
# lay_32dn (None, 32, 32, 256)
# lay_16dn (None, 16, 16, 512)
# lay_8dn (None, 8, 8, 512)
# lay_16up (None, 16, 16, 1024)
# (None, 16, 16, 1536)
# lay_32up (None, 32, 32, 256)
# lay_64up (None, 64, 64, 128)
# lay_128up (None, 128, 128, 64)
# lay_256up (None, 256, 256, 64)
# Model: "model_21"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_40 (InputLayer)       [(None, 256, 256, 2)]        0         []
#
#  conv2d_2004 (Conv2D)        (None, 128, 128, 64)         2112      ['input_40[0][0]']
#
#  leaky_re_lu_1646 (LeakyReL  (None, 128, 128, 64)         0         ['conv2d_2004[0][0]']
#  U)
#
#  conv2d_2005 (Conv2D)        (None, 64, 64, 128)          131200    ['leaky_re_lu_1646[0][0]']
#
#  batch_normalization_1607 (  (None, 64, 64, 128)          512       ['conv2d_2005[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1647 (LeakyReL  (None, 64, 64, 128)          0         ['batch_normalization_1607[0][
#  U)                                                                 0]']
#
#  conv2d_2006 (Conv2D)        (None, 32, 32, 256)          524544    ['leaky_re_lu_1647[0][0]']
#
#  batch_normalization_1608 (  (None, 32, 32, 256)          1024      ['conv2d_2006[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1648 (LeakyReL  (None, 32, 32, 256)          0         ['batch_normalization_1608[0][
#  U)                                                                 0]']
#
#  conv2d_2007 (Conv2D)        (None, 16, 16, 512)          2097664   ['leaky_re_lu_1648[0][0]']
#
#  batch_normalization_1609 (  (None, 16, 16, 512)          2048      ['conv2d_2007[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1649 (LeakyReL  (None, 16, 16, 512)          0         ['batch_normalization_1609[0][
#  U)                                                                 0]']
#
#  conv2d_2008 (Conv2D)        (None, 8, 8, 512)            4194816   ['leaky_re_lu_1649[0][0]']
#
#  batch_normalization_1610 (  (None, 8, 8, 512)            2048      ['conv2d_2008[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1650 (LeakyReL  (None, 8, 8, 512)            0         ['batch_normalization_1610[0][
#  U)                                                                 0]']
#
#  conv2d_2009 (Conv2D)        (None, 8, 8, 512)            2359808   ['leaky_re_lu_1650[0][0]']
#
#  conv2d_2010 (Conv2D)        (None, 8, 8, 32)             147488    ['conv2d_2009[0][0]']
#
#  batch_normalization_1611 (  (None, 8, 8, 32)             128       ['conv2d_2010[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1651 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1611[0][
#  U)                                                                 0]']
#
#  concatenate_1324 (Concaten  (None, 8, 8, 544)            0         ['conv2d_2009[0][0]',
#  ate)                                                                'leaky_re_lu_1651[0][0]']
#
#  conv2d_2011 (Conv2D)        (None, 8, 8, 32)             156704    ['concatenate_1324[0][0]']
#
#  batch_normalization_1612 (  (None, 8, 8, 32)             128       ['conv2d_2011[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1652 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1612[0][
#  U)                                                                 0]']
#
#  concatenate_1325 (Concaten  (None, 8, 8, 576)            0         ['concatenate_1324[0][0]',
#  ate)                                                                'leaky_re_lu_1652[0][0]']
#
#  conv2d_2012 (Conv2D)        (None, 8, 8, 32)             165920    ['concatenate_1325[0][0]']
#
#  batch_normalization_1613 (  (None, 8, 8, 32)             128       ['conv2d_2012[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1653 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1613[0][
#  U)                                                                 0]']
#
#  concatenate_1326 (Concaten  (None, 8, 8, 608)            0         ['concatenate_1325[0][0]',
#  ate)                                                                'leaky_re_lu_1653[0][0]']
#
#  conv2d_2013 (Conv2D)        (None, 8, 8, 32)             175136    ['concatenate_1326[0][0]']
#
#  batch_normalization_1614 (  (None, 8, 8, 32)             128       ['conv2d_2013[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1654 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1614[0][
#  U)                                                                 0]']
#
#  concatenate_1327 (Concaten  (None, 8, 8, 640)            0         ['concatenate_1326[0][0]',
#  ate)                                                                'leaky_re_lu_1654[0][0]']
#
#  conv2d_2014 (Conv2D)        (None, 8, 8, 512)            2949632   ['concatenate_1327[0][0]']
#
#  lambda_434 (Lambda)         (None, 8, 8, 512)            0         ['conv2d_2014[0][0]']
#
#  add_464 (Add)               (None, 8, 8, 512)            0         ['lambda_434[0][0]',
#                                                                      'conv2d_2009[0][0]']
#
#  conv2d_2015 (Conv2D)        (None, 8, 8, 32)             147488    ['add_464[0][0]']
#
#  batch_normalization_1615 (  (None, 8, 8, 32)             128       ['conv2d_2015[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1655 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1615[0][
#  U)                                                                 0]']
#
#  concatenate_1328 (Concaten  (None, 8, 8, 544)            0         ['add_464[0][0]',
#  ate)                                                                'leaky_re_lu_1655[0][0]']
#
#  conv2d_2016 (Conv2D)        (None, 8, 8, 32)             156704    ['concatenate_1328[0][0]']
#
#  batch_normalization_1616 (  (None, 8, 8, 32)             128       ['conv2d_2016[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1656 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1616[0][
#  U)                                                                 0]']
#
#  concatenate_1329 (Concaten  (None, 8, 8, 576)            0         ['concatenate_1328[0][0]',
#  ate)                                                                'leaky_re_lu_1656[0][0]']
#
#  conv2d_2017 (Conv2D)        (None, 8, 8, 32)             165920    ['concatenate_1329[0][0]']
#
#  batch_normalization_1617 (  (None, 8, 8, 32)             128       ['conv2d_2017[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1657 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1617[0][
#  U)                                                                 0]']
#
#  concatenate_1330 (Concaten  (None, 8, 8, 608)            0         ['concatenate_1329[0][0]',
#  ate)                                                                'leaky_re_lu_1657[0][0]']
#
#  conv2d_2018 (Conv2D)        (None, 8, 8, 32)             175136    ['concatenate_1330[0][0]']
#
#  batch_normalization_1618 (  (None, 8, 8, 32)             128       ['conv2d_2018[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1658 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1618[0][
#  U)                                                                 0]']
#
#  concatenate_1331 (Concaten  (None, 8, 8, 640)            0         ['concatenate_1330[0][0]',
#  ate)                                                                'leaky_re_lu_1658[0][0]']
#
#  conv2d_2019 (Conv2D)        (None, 8, 8, 512)            2949632   ['concatenate_1331[0][0]']
#
#  lambda_435 (Lambda)         (None, 8, 8, 512)            0         ['conv2d_2019[0][0]']
#
#  add_465 (Add)               (None, 8, 8, 512)            0         ['lambda_435[0][0]',
#                                                                      'add_464[0][0]']
#
#  conv2d_2020 (Conv2D)        (None, 8, 8, 32)             147488    ['add_465[0][0]']
#
#  batch_normalization_1619 (  (None, 8, 8, 32)             128       ['conv2d_2020[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1659 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1619[0][
#  U)                                                                 0]']
#
#  concatenate_1332 (Concaten  (None, 8, 8, 544)            0         ['add_465[0][0]',
#  ate)                                                                'leaky_re_lu_1659[0][0]']
#
#  conv2d_2021 (Conv2D)        (None, 8, 8, 32)             156704    ['concatenate_1332[0][0]']
#
#  batch_normalization_1620 (  (None, 8, 8, 32)             128       ['conv2d_2021[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1660 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1620[0][
#  U)                                                                 0]']
#
#  concatenate_1333 (Concaten  (None, 8, 8, 576)            0         ['concatenate_1332[0][0]',
#  ate)                                                                'leaky_re_lu_1660[0][0]']
#
#  conv2d_2022 (Conv2D)        (None, 8, 8, 32)             165920    ['concatenate_1333[0][0]']
#
#  batch_normalization_1621 (  (None, 8, 8, 32)             128       ['conv2d_2022[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1661 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1621[0][
#  U)                                                                 0]']
#
#  concatenate_1334 (Concaten  (None, 8, 8, 608)            0         ['concatenate_1333[0][0]',
#  ate)                                                                'leaky_re_lu_1661[0][0]']
#
#  conv2d_2023 (Conv2D)        (None, 8, 8, 32)             175136    ['concatenate_1334[0][0]']
#
#  batch_normalization_1622 (  (None, 8, 8, 32)             128       ['conv2d_2023[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1662 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1622[0][
#  U)                                                                 0]']
#
#  concatenate_1335 (Concaten  (None, 8, 8, 640)            0         ['concatenate_1334[0][0]',
#  ate)                                                                'leaky_re_lu_1662[0][0]']
#
#  conv2d_2024 (Conv2D)        (None, 8, 8, 512)            2949632   ['concatenate_1335[0][0]']
#
#  lambda_436 (Lambda)         (None, 8, 8, 512)            0         ['conv2d_2024[0][0]']
#
#  add_466 (Add)               (None, 8, 8, 512)            0         ['lambda_436[0][0]',
#                                                                      'add_465[0][0]']
#
#  lambda_437 (Lambda)         (None, 8, 8, 512)            0         ['add_466[0][0]']
#
#  add_467 (Add)               (None, 8, 8, 512)            0         ['lambda_437[0][0]',
#                                                                      'conv2d_2009[0][0]']
#
#  conv2d_2025 (Conv2D)        (None, 8, 8, 32)             147488    ['add_467[0][0]']
#
#  batch_normalization_1623 (  (None, 8, 8, 32)             128       ['conv2d_2025[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1663 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1623[0][
#  U)                                                                 0]']
#
#  concatenate_1336 (Concaten  (None, 8, 8, 544)            0         ['add_467[0][0]',
#  ate)                                                                'leaky_re_lu_1663[0][0]']
#
#  conv2d_2026 (Conv2D)        (None, 8, 8, 32)             156704    ['concatenate_1336[0][0]']
#
#  batch_normalization_1624 (  (None, 8, 8, 32)             128       ['conv2d_2026[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1664 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1624[0][
#  U)                                                                 0]']
#
#  concatenate_1337 (Concaten  (None, 8, 8, 576)            0         ['concatenate_1336[0][0]',
#  ate)                                                                'leaky_re_lu_1664[0][0]']
#
#  conv2d_2027 (Conv2D)        (None, 8, 8, 32)             165920    ['concatenate_1337[0][0]']
#
#  batch_normalization_1625 (  (None, 8, 8, 32)             128       ['conv2d_2027[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1665 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1625[0][
#  U)                                                                 0]']
#
#  concatenate_1338 (Concaten  (None, 8, 8, 608)            0         ['concatenate_1337[0][0]',
#  ate)                                                                'leaky_re_lu_1665[0][0]']
#
#  conv2d_2028 (Conv2D)        (None, 8, 8, 32)             175136    ['concatenate_1338[0][0]']
#
#  batch_normalization_1626 (  (None, 8, 8, 32)             128       ['conv2d_2028[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1666 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1626[0][
#  U)                                                                 0]']
#
#  concatenate_1339 (Concaten  (None, 8, 8, 640)            0         ['concatenate_1338[0][0]',
#  ate)                                                                'leaky_re_lu_1666[0][0]']
#
#  conv2d_2029 (Conv2D)        (None, 8, 8, 512)            2949632   ['concatenate_1339[0][0]']
#
#  lambda_438 (Lambda)         (None, 8, 8, 512)            0         ['conv2d_2029[0][0]']
#
#  add_468 (Add)               (None, 8, 8, 512)            0         ['lambda_438[0][0]',
#                                                                      'add_467[0][0]']
#
#  conv2d_2030 (Conv2D)        (None, 8, 8, 32)             147488    ['add_468[0][0]']
#
#  batch_normalization_1627 (  (None, 8, 8, 32)             128       ['conv2d_2030[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1667 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1627[0][
#  U)                                                                 0]']
#
#  concatenate_1340 (Concaten  (None, 8, 8, 544)            0         ['add_468[0][0]',
#  ate)                                                                'leaky_re_lu_1667[0][0]']
#
#  conv2d_2031 (Conv2D)        (None, 8, 8, 32)             156704    ['concatenate_1340[0][0]']
#
#  batch_normalization_1628 (  (None, 8, 8, 32)             128       ['conv2d_2031[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1668 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1628[0][
#  U)                                                                 0]']
#
#  concatenate_1341 (Concaten  (None, 8, 8, 576)            0         ['concatenate_1340[0][0]',
#  ate)                                                                'leaky_re_lu_1668[0][0]']
#
#  conv2d_2032 (Conv2D)        (None, 8, 8, 32)             165920    ['concatenate_1341[0][0]']
#
#  batch_normalization_1629 (  (None, 8, 8, 32)             128       ['conv2d_2032[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1669 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1629[0][
#  U)                                                                 0]']
#
#  concatenate_1342 (Concaten  (None, 8, 8, 608)            0         ['concatenate_1341[0][0]',
#  ate)                                                                'leaky_re_lu_1669[0][0]']
#
#  conv2d_2033 (Conv2D)        (None, 8, 8, 32)             175136    ['concatenate_1342[0][0]']
#
#  batch_normalization_1630 (  (None, 8, 8, 32)             128       ['conv2d_2033[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1670 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1630[0][
#  U)                                                                 0]']
#
#  concatenate_1343 (Concaten  (None, 8, 8, 640)            0         ['concatenate_1342[0][0]',
#  ate)                                                                'leaky_re_lu_1670[0][0]']
#
#  conv2d_2034 (Conv2D)        (None, 8, 8, 512)            2949632   ['concatenate_1343[0][0]']
#
#  lambda_439 (Lambda)         (None, 8, 8, 512)            0         ['conv2d_2034[0][0]']
#
#  add_469 (Add)               (None, 8, 8, 512)            0         ['lambda_439[0][0]',
#                                                                      'add_468[0][0]']
#
#  conv2d_2035 (Conv2D)        (None, 8, 8, 32)             147488    ['add_469[0][0]']
#
#  batch_normalization_1631 (  (None, 8, 8, 32)             128       ['conv2d_2035[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1671 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1631[0][
#  U)                                                                 0]']
#
#  concatenate_1344 (Concaten  (None, 8, 8, 544)            0         ['add_469[0][0]',
#  ate)                                                                'leaky_re_lu_1671[0][0]']
#
#  conv2d_2036 (Conv2D)        (None, 8, 8, 32)             156704    ['concatenate_1344[0][0]']
#
#  batch_normalization_1632 (  (None, 8, 8, 32)             128       ['conv2d_2036[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1672 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1632[0][
#  U)                                                                 0]']
#
#  concatenate_1345 (Concaten  (None, 8, 8, 576)            0         ['concatenate_1344[0][0]',
#  ate)                                                                'leaky_re_lu_1672[0][0]']
#
#  conv2d_2037 (Conv2D)        (None, 8, 8, 32)             165920    ['concatenate_1345[0][0]']
#
#  batch_normalization_1633 (  (None, 8, 8, 32)             128       ['conv2d_2037[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1673 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1633[0][
#  U)                                                                 0]']
#
#  concatenate_1346 (Concaten  (None, 8, 8, 608)            0         ['concatenate_1345[0][0]',
#  ate)                                                                'leaky_re_lu_1673[0][0]']
#
#  conv2d_2038 (Conv2D)        (None, 8, 8, 32)             175136    ['concatenate_1346[0][0]']
#
#  batch_normalization_1634 (  (None, 8, 8, 32)             128       ['conv2d_2038[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1674 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1634[0][
#  U)                                                                 0]']
#
#  concatenate_1347 (Concaten  (None, 8, 8, 640)            0         ['concatenate_1346[0][0]',
#  ate)                                                                'leaky_re_lu_1674[0][0]']
#
#  conv2d_2039 (Conv2D)        (None, 8, 8, 512)            2949632   ['concatenate_1347[0][0]']
#
#  lambda_440 (Lambda)         (None, 8, 8, 512)            0         ['conv2d_2039[0][0]']
#
#  add_470 (Add)               (None, 8, 8, 512)            0         ['lambda_440[0][0]',
#                                                                      'add_469[0][0]']
#
#  lambda_441 (Lambda)         (None, 8, 8, 512)            0         ['add_470[0][0]']
#
#  add_471 (Add)               (None, 8, 8, 512)            0         ['lambda_441[0][0]',
#                                                                      'add_467[0][0]']
#
#  conv2d_2040 (Conv2D)        (None, 8, 8, 32)             147488    ['add_471[0][0]']
#
#  batch_normalization_1635 (  (None, 8, 8, 32)             128       ['conv2d_2040[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1675 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1635[0][
#  U)                                                                 0]']
#
#  concatenate_1348 (Concaten  (None, 8, 8, 544)            0         ['add_471[0][0]',
#  ate)                                                                'leaky_re_lu_1675[0][0]']
#
#  conv2d_2041 (Conv2D)        (None, 8, 8, 32)             156704    ['concatenate_1348[0][0]']
#
#  batch_normalization_1636 (  (None, 8, 8, 32)             128       ['conv2d_2041[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1676 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1636[0][
#  U)                                                                 0]']
# ...
#
#  leaky_re_lu_1789 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1749[0][
#  U)                                                                 0]']
#
#  concatenate_1462 (Concaten  (None, 8, 8, 608)            0         ['concatenate_1461[0][0]',
#  ate)                                                                'leaky_re_lu_1789[0][0]']
#
#  conv2d_2183 (Conv2D)        (None, 8, 8, 32)             175136    ['concatenate_1462[0][0]']
#
#  batch_normalization_1750 (  (None, 8, 8, 32)             128       ['conv2d_2183[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1790 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1750[0][
#  U)                                                                 0]']
#
#  concatenate_1463 (Concaten  (None, 8, 8, 640)            0         ['concatenate_1462[0][0]',
#  ate)                                                                'leaky_re_lu_1790[0][0]']
#
#  conv2d_2184 (Conv2D)        (None, 8, 8, 512)            2949632   ['concatenate_1463[0][0]']
#
#  lambda_479 (Lambda)         (None, 8, 8, 512)            0         ['conv2d_2184[0][0]']
#
#  add_509 (Add)               (None, 8, 8, 512)            0         ['lambda_479[0][0]',
#                                                                      'add_508[0][0]']
#
#  conv2d_2185 (Conv2D)        (None, 8, 8, 32)             147488    ['add_509[0][0]']
#
#  batch_normalization_1751 (  (None, 8, 8, 32)             128       ['conv2d_2185[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1791 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1751[0][
#  U)                                                                 0]']
#
#  concatenate_1464 (Concaten  (None, 8, 8, 544)            0         ['add_509[0][0]',
#  ate)                                                                'leaky_re_lu_1791[0][0]']
#
#  conv2d_2186 (Conv2D)        (None, 8, 8, 32)             156704    ['concatenate_1464[0][0]']
#
#  batch_normalization_1752 (  (None, 8, 8, 32)             128       ['conv2d_2186[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1792 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1752[0][
#  U)                                                                 0]']
#
#  concatenate_1465 (Concaten  (None, 8, 8, 576)            0         ['concatenate_1464[0][0]',
#  ate)                                                                'leaky_re_lu_1792[0][0]']
#
#  conv2d_2187 (Conv2D)        (None, 8, 8, 32)             165920    ['concatenate_1465[0][0]']
#
#  batch_normalization_1753 (  (None, 8, 8, 32)             128       ['conv2d_2187[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1793 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1753[0][
#  U)                                                                 0]']
#
#  concatenate_1466 (Concaten  (None, 8, 8, 608)            0         ['concatenate_1465[0][0]',
#  ate)                                                                'leaky_re_lu_1793[0][0]']
#
#  conv2d_2188 (Conv2D)        (None, 8, 8, 32)             175136    ['concatenate_1466[0][0]']
#
#  batch_normalization_1754 (  (None, 8, 8, 32)             128       ['conv2d_2188[0][0]']
#  BatchNormalization)
#
#  leaky_re_lu_1794 (LeakyReL  (None, 8, 8, 32)             0         ['batch_normalization_1754[0][
#  U)                                                                 0]']
#
#  concatenate_1467 (Concaten  (None, 8, 8, 640)            0         ['concatenate_1466[0][0]',
#  ate)                                                                'leaky_re_lu_1794[0][0]']
#
#  conv2d_2189 (Conv2D)        (None, 8, 8, 512)            2949632   ['concatenate_1467[0][0]']
#
#  lambda_480 (Lambda)         (None, 8, 8, 512)            0         ['conv2d_2189[0][0]']
#
#  add_510 (Add)               (None, 8, 8, 512)            0         ['lambda_480[0][0]',
#                                                                      'add_509[0][0]']
#
#  lambda_481 (Lambda)         (None, 8, 8, 512)            0         ['add_510[0][0]']
#
#  add_511 (Add)               (None, 8, 8, 512)            0         ['lambda_481[0][0]',
#                                                                      'add_507[0][0]']
#
#  conv2d_2190 (Conv2D)        (None, 8, 8, 512)            2359808   ['add_511[0][0]']
#
#  add_512 (Add)               (None, 8, 8, 512)            0         ['conv2d_2009[0][0]',
#                                                                      'conv2d_2190[0][0]']
#
#  conv2d_transpose_13 (Conv2  (None, 16, 16, 1024)         8389632   ['add_512[0][0]']
#  DTranspose)
#
#  batch_normalization_1755 (  (None, 16, 16, 1024)         4096      ['conv2d_transpose_13[0][0]']
#  BatchNormalization)
#
#  activation_21 (Activation)  (None, 16, 16, 1024)         0         ['batch_normalization_1755[0][
#                                                                     0]']
#
#  concatenate_1468 (Concaten  (None, 16, 16, 1536)         0         ['activation_21[0][0]',
#  ate)                                                                'leaky_re_lu_1649[0][0]']
#
#  conv2d_transpose_14 (Conv2  (None, 32, 32, 256)          6291712   ['concatenate_1468[0][0]']
#  DTranspose)
#
#  batch_normalization_1756 (  (None, 32, 32, 256)          1024      ['conv2d_transpose_14[0][0]']
#  BatchNormalization)
#
#  activation_22 (Activation)  (None, 32, 32, 256)          0         ['batch_normalization_1756[0][
#                                                                     0]']
#
#  concatenate_1469 (Concaten  (None, 32, 32, 512)          0         ['activation_22[0][0]',
#  ate)                                                                'leaky_re_lu_1648[0][0]']
#
#  conv2d_transpose_15 (Conv2  (None, 64, 64, 128)          1048704   ['concatenate_1469[0][0]']
#  DTranspose)
#
#  batch_normalization_1757 (  (None, 64, 64, 128)          512       ['conv2d_transpose_15[0][0]']
#  BatchNormalization)
#
#  activation_23 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_1757[0][
#                                                                     0]']
#
#  concatenate_1470 (Concaten  (None, 64, 64, 256)          0         ['activation_23[0][0]',
#  ate)                                                                'leaky_re_lu_1647[0][0]']
#
#  conv2d_transpose_16 (Conv2  (None, 128, 128, 64)         262208    ['concatenate_1470[0][0]']
#  DTranspose)
#
#  batch_normalization_1758 (  (None, 128, 128, 64)         256       ['conv2d_transpose_16[0][0]']
#  BatchNormalization)
#
#  activation_24 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_1758[0][
#                                                                     0]']
#
#  concatenate_1471 (Concaten  (None, 128, 128, 128)        0         ['activation_24[0][0]',
#  ate)                                                                'leaky_re_lu_1646[0][0]']
#
#  conv2d_transpose_17 (Conv2  (None, 256, 256, 64)         131136    ['concatenate_1471[0][0]']
#  DTranspose)
#
#  batch_normalization_1759 (  (None, 256, 256, 64)         256       ['conv2d_transpose_17[0][0]']
#  BatchNormalization)
#
#  activation_25 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_1759[0][
#                                                                     0]']
#
#  conv2d_2191 (Conv2D)        (None, 256, 256, 1)          65        ['activation_25[0][0]']
#
# ==================================================================================================
# Total params: 157239297 (599.82 MB)
# Trainable params: 157224193 (599.76 MB)
# Non-trainable params: 15104 (59.00 KB)
# __________________________________________________________________________________________________
# Model: "model_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_41 (InputLayer)       [(None, 256, 256, 2)]     0
#
#  model_21 (Functional)       (None, 256, 256, 1)       157239297
#
#  model_20 (Functional)       (None, 1, 1, 1)           87723585
#
# =================================================================
# Total params: 244962882 (934.46 MB)
# Trainable params: 157224193 (599.76 MB)
# Non-trainable params: 87738689 (334.70 MB)
# _________________________________________________________________
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[104], line 31
#      28 n_patch = d_model.output_shape[1]
#      30 f = open('./log_a5.txt' , 'a')
# ---> 31 train(g_par, d_par, gan_model, dataset_real, u_sampled_data_2c, n_epochs, n_batch, n_critic, clip_val, n_patch, f)
#
# NameError: name 'u_sampled_data_2c' is not defined

# %% [markdown]
# # Test Model

# %%
def metrics(true_tensor, test_tensor, max_val):
    
    psnrt = 0
    ssimt = 0
    
    
    for i in range(true_tensor.shape[0]):
        
        true_image = np.squeeze(true_tensor[i,:,:])
        test_image = np.squeeze(test_tensor[i,:,:])
        
        psnr = peak_signal_noise_ratio(true_image, test_image, data_range=max_val)
        
        ssim = structural_similarity(true_image, test_image, data_range=max_val)
        psnrt = psnrt + psnr
        
        ssimt = ssimt + ssim
        
        psnrt = psnrt/true_tensor.shape[0]
        ssimt = ssimt/true_tensor.shape[0]
        
        return psnrt, ssimt

# %%
# data_path = 'preprocessed_data/training.pickle'
# usam_path = 'preprocessed_data/training_usamp.pickle'
# dataset_real = pickle.load(open(data_path,'rb'))
# u_sampled_data = pickle.load(open(usam_path,'rb'))
                             

                             
data = np.asarray(dataset_real, dtype ='float32')
usp_data = np.expand_dims(u_sampled_data, axis = -1)
data_gen = np.concatenate((usp_data.real,usp_data.imag), axis = -1)

# %%
gen16 = generator(inp_shape = (256,256,2), trainable = False)
gen16.load_weights('gen_weights/gen_weights_a5_0004.h5')

out16 = gen16.predict(data_gen)

psnr, ssim = metrics(data, out16[:,:,:,0], 2.0)

print(psnr, ssim)

# %%
plot_no = 1

fig, ax = plt.subplots(1,3, figsize=(20,5))
ax[0].imshow(data[plot_no],cmap='gray')
ax[0].set_title('Ground Truth')
ax[1].imshow(np.squeeze(usp_data[plot_no].real), cmap ='gray')
ax[1].set_title('Undersampled Image')
ax[2].imshow(np.squeeze(out16[plot_no]), cmap='gray')
ax[2].set_title('Reconstructed  Image')
plt.show
