# %% [markdown]
# # Project : Undersampled MRI Reconstruction

# %% [markdown]
# **Importing Dependencies**

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import time
import os
from skimage.metrics import structural_similarity as ssim
import tensorflow as tf
import sklearn
from sklearn.model_selection import train_test_split
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# **Writing Basic Functions**
#
# This function converts data from image domain to frequency domain (Image to Kspace)

# %%
def citf(image):
    tmp = np.fft.fftshift(cv2.dft(np.float32(image), flags=cv2.DFT_COMPLEX_OUTPUT))
    complex_matrix = tmp[:,:,0] + 1j * tmp[:,:,1]
    return complex_matrix

# %% [markdown]
# This function converts data from frequency domain to Image domain (Kspace to Image)

# %%
def cfti(kspace):
    img_inverse = np.flipud(np.fliplr(np.abs(np.fft.ifft2(kspace))))
    return img_inverse

# %% [markdown]
# This function takes kspace as input and displays the data in both the image and frequency domain

# %%
def show_both(kspace):
    mag_spe = 20*np.log(np.abs(kspace))
    plt.subplot(121), plt.imshow(cfti(kspace), cmap='gray')
    plt.title('Input Image'), plt.xticks([]), plt.yticks([])
    plt.subplot(122), plt.imshow(mag_spe, cmap='gray')
    plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
    plt.show()

# %% [markdown]
# This function takes two kspace data and display their images

# %%
def diff(t_kspace , u_kspace):
    plt.subplot(121), plt.imshow(cfti(t_kspace), cmap='gray')
    plt.title('Ground Truth'), plt.xticks([]), plt.yticks([])
    plt.subplot(122), plt.imshow(cfti(u_kspace), cmap='gray')
    plt.title('Undersampled Image'), plt.xticks([]), plt.yticks([])
    plt.show()

# %% [markdown]
# # Data Collection
#
# This part we read the data from the kaggle dataset and store in an numpy array so that we can work on it

# %%
images = []
def process_file(file_path):
    if "mask" in file_path or "README" in file_path or ".csv" in file_path:
        time.sleep(0)
    else:
        image = cv2.imread(file_path,0)
        image = np.array(image)
        image = image.astype('float32') / 255.0
        images.append(image)
        return
for folder_name, subfolders, filenames in os.walk("/kaggle/input/lgg-mri-segmentation/kaggle_3m"):
    for filename in filenames:
        if "mask" not in filename:
            file_path = os.path.join(folder_name, filename)
            process_file(file_path)
images = np.asarray(images)

# %% [markdown]
# # Data preprocessing
#
# Since we want to undersample our data therefore we need to convert our data from image to frequency domain

# %%
kspaces = []
for image in images:
    kspace = citf(image)
    kspaces.append(np.array(kspace))
kspaces = np.asarray(kspaces)

# %% [markdown]
# # Undersampling the kspace data
#
# Now we need to undersample our data.
#
# **For this we need to undersample our data in such a way which will decrease the acquisition time and also it is feasible to collect that undersampled data from MRI machine**
#
# Therefore we have chosen an cartesian undersampling.
#
# Preparing mask to undersample the kspace data.

# %%
mask = np.zeros((256,256))
mask[112:144,:] = np.ones((32,256))
plt.imshow(mask, cmap='gray')

# %%
def unsample_data(data, mask):
    u_kspaces = []
    u_images = []
    for i in range(kspaces.shape[0]):
        u_kspace = np.multiply(kspaces[i,:,:], mask)
        u_kspaces.append(u_kspace)
        u_images.append(cfti(u_kspace))
    return np.array(u_kspaces) , np.array(u_images)

# %%
u_kspaces , u_images = unsample_data(kspaces,mask)

# %% [markdown]
# At this stage we have preprocessed the data and we have fullysampled kspaces , their corresponding images , undersampled kspaces and their corresponding images.
#
# **We will store this in a file so that we don't require to do this much processing again and again. We will directly read this data from this file if we want to use it again.**

# %%
np.savez('data.npz',kspaces=kspaces , u_kspaces = u_kspaces , images=images , u_images=u_images)

# %%
import numpy as np
data = np.load('data.npz')
kspaces = data['kspaces']
u_kspaces = data['u_kspaces']
images = data['images']
u_images = data['u_images']

# %% [markdown]
# **This example shows the undersampled kspace and its corresponding image**
#
# **You can notice that the image is blurred and most of the fine details of the MRI images are gone**

# %%
show_both(u_kspaces[100,:,:])
# Out:
# /tmp/ipykernel_1909/3086757226.py:2: RuntimeWarning: divide by zero encountered in log
#   mag_spe = 20*np.log(np.abs(kspace))

# %% [markdown]
# **Comparison between Fullysampled MRI image and Undersampled MRI image**

# %%
diff(kspaces[100,:,:],u_kspaces[100,:,:])

# %% [markdown]
# # Spliting the Data into train and test data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(u_images , images , test_size=0.2, random_state=42)

# %% [markdown]
# # Creating a model architechture
#
# This model is being inspired from the **ReconResNet: Regularised Residual Learning for MR Image Reconstruction of Undersampled Cartesian and Radial Data**
#
# Link of the paper : https://arxiv.org/pdf/2103.09203.pdf

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers

def ssim_loss(y_true, y_pred):
    return 1 - tf.reduce_mean(tf.image.ssim(y_true, y_pred, 1.0))

def res_block(x, filters, kernel_size=3, stride=1, padding='same'):
    """Residual block."""
    res = x
    x = layers.Conv2D(filters, kernel_size, strides=stride, padding=padding, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(filters, kernel_size, strides=stride, padding=padding)(x)
    x = layers.BatchNormalization()(x)
    x = layers.add([x, res])
    x = layers.Activation('relu')(x)
    return x

def ResNet(input_shape, num_residual_blocks):
    """Builds the ResNet."""
    inputs = layers.Input(shape=input_shape)
    x = inputs
    
    # Input Down-sampling
    x = layers.Conv2D(64, (3, 3), strides=2, padding='same', activation='relu')(x)
    x = layers.Conv2D(64, (3, 3), strides=2, padding='same', activation='relu')(x)
    
    # Residual Blocks
    for _ in range(num_residual_blocks):
        x = res_block(x, 64)
    
    # Output Up-sampling
    x = layers.Conv2DTranspose(64, (3, 3), strides=2, padding='same', activation='relu')(x)
    x = layers.Conv2DTranspose(64, (3, 3), strides=2, padding='same', activation='relu')(x)
    
    # Final Convolution Layer
    outputs = layers.Conv2D(1, (7, 7), strides=1, padding='same', activation='sigmoid')(x)
    
    # Define the model
    model = models.Model(inputs, outputs)
    
    # Compile the model
    model.compile(optimizer=optimizers.Adam(learning_rate=0.001),loss=ssim_loss)
    
    return model

# Set input shape and number of residual blocks based on the paper
input_shape = (256,256, 1)  # Assuming grayscale MRI images with variable size
num_residual_blocks = 34

# Create the model
model = ResNet(input_shape, num_residual_blocks)

# Model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 64  640         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 64)   36928       ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 64)   36928       ['conv2d_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 64, 64, 64)  256         ['conv2d_2[0][0]']
#  alization)
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 64)   36928       ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 64, 64, 64)   0           ['batch_normalization_1[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  activation (Activation)        (None, 64, 64, 64)   0           ['add[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 64)   36928       ['activation[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 64)   36928       ['batch_normalization_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 64, 64, 64)   0           ['batch_normalization_3[0][0]',
#                                                                   'activation[0][0]']
#
#  activation_1 (Activation)      (None, 64, 64, 64)   0           ['add_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 64)   36928       ['activation_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 64)   36928       ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 64, 64, 64)   0           ['batch_normalization_5[0][0]',
#                                                                   'activation_1[0][0]']
#
#  activation_2 (Activation)      (None, 64, 64, 64)   0           ['add_2[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 64)   36928       ['activation_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 64)   36928       ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 64, 64, 64)   0           ['batch_normalization_7[0][0]',
#                                                                   'activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 64, 64, 64)   0           ['add_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_10[0][0]']
#  rmalization)
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_11[0][0]']
#  rmalization)
#
#  add_4 (Add)                    (None, 64, 64, 64)   0           ['batch_normalization_9[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_4 (Activation)      (None, 64, 64, 64)   0           ['add_4[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_4[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 64, 64, 64)   0           ['batch_normalization_11[0][0]',
#                                                                   'activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 64, 64, 64)   0           ['add_5[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_5[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 64)  256         ['conv2d_14[0][0]']
#  ormalization)
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 64, 64, 64)  256         ['conv2d_15[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 64, 64, 64)   0           ['batch_normalization_13[0][0]',
#                                                                   'activation_5[0][0]']
#
#  activation_6 (Activation)      (None, 64, 64, 64)   0           ['add_6[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_6[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 64, 64, 64)  256         ['conv2d_16[0][0]']
#  ormalization)
#
#  conv2d_17 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 64)  256         ['conv2d_17[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 64, 64, 64)   0           ['batch_normalization_15[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_7 (Activation)      (None, 64, 64, 64)   0           ['add_7[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_7[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 64, 64, 64)  256         ['conv2d_18[0][0]']
#  ormalization)
#
#  conv2d_19 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 64, 64, 64)  256         ['conv2d_19[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 64, 64, 64)   0           ['batch_normalization_17[0][0]',
#                                                                   'activation_7[0][0]']
#
#  activation_8 (Activation)      (None, 64, 64, 64)   0           ['add_8[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_8[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 64, 64, 64)  256         ['conv2d_20[0][0]']
#  ormalization)
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 64, 64, 64)  256         ['conv2d_21[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 64, 64, 64)   0           ['batch_normalization_19[0][0]',
#                                                                   'activation_8[0][0]']
#
#  activation_9 (Activation)      (None, 64, 64, 64)   0           ['add_9[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_9[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 64, 64, 64)  256         ['conv2d_22[0][0]']
#  ormalization)
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 64, 64, 64)  256         ['conv2d_23[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_21[0][0]',
#                                                                   'activation_9[0][0]']
#
#  activation_10 (Activation)     (None, 64, 64, 64)   0           ['add_10[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_10[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 64, 64, 64)  256         ['conv2d_24[0][0]']
#  ormalization)
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 64, 64, 64)  256         ['conv2d_25[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_23[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_11 (Activation)     (None, 64, 64, 64)   0           ['add_11[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_11[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 64, 64, 64)  256         ['conv2d_26[0][0]']
#  ormalization)
#
#  conv2d_27 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 64, 64, 64)  256         ['conv2d_27[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_25[0][0]',
#                                                                   'activation_11[0][0]']
#
#  activation_12 (Activation)     (None, 64, 64, 64)   0           ['add_12[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_12[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 64, 64, 64)  256         ['conv2d_28[0][0]']
#  ormalization)
#
#  conv2d_29 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 64, 64, 64)  256         ['conv2d_29[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_27[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_13 (Activation)     (None, 64, 64, 64)   0           ['add_13[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_13[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 64, 64, 64)  256         ['conv2d_30[0][0]']
#  ormalization)
#
#  conv2d_31 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 64, 64, 64)  256         ['conv2d_31[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_29[0][0]',
#                                                                   'activation_13[0][0]']
#
#  activation_14 (Activation)     (None, 64, 64, 64)   0           ['add_14[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_14[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 64, 64, 64)  256         ['conv2d_32[0][0]']
#  ormalization)
#
#  conv2d_33 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 64, 64, 64)  256         ['conv2d_33[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_31[0][0]',
#                                                                   'activation_14[0][0]']
#
#  activation_15 (Activation)     (None, 64, 64, 64)   0           ['add_15[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_15[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 64, 64, 64)  256         ['conv2d_34[0][0]']
#  ormalization)
#
#  conv2d_35 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 64, 64, 64)  256         ['conv2d_35[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_33[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_16 (Activation)     (None, 64, 64, 64)   0           ['add_16[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_16[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 64, 64, 64)  256         ['conv2d_36[0][0]']
#  ormalization)
#
#  conv2d_37 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 64, 64, 64)  256         ['conv2d_37[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_35[0][0]',
#                                                                   'activation_16[0][0]']
#
#  activation_17 (Activation)     (None, 64, 64, 64)   0           ['add_17[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_17[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 64, 64, 64)  256         ['conv2d_38[0][0]']
#  ormalization)
#
#  conv2d_39 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 64, 64, 64)  256         ['conv2d_39[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_37[0][0]',
#                                                                   'activation_17[0][0]']
#
#  activation_18 (Activation)     (None, 64, 64, 64)   0           ['add_18[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_18[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 64, 64, 64)  256         ['conv2d_40[0][0]']
#  ormalization)
#
#  conv2d_41 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 64, 64, 64)  256         ['conv2d_41[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_39[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_19 (Activation)     (None, 64, 64, 64)   0           ['add_19[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_19[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 64, 64, 64)  256         ['conv2d_42[0][0]']
#  ormalization)
#
#  conv2d_43 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 64, 64, 64)  256         ['conv2d_43[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_41[0][0]',
#                                                                   'activation_19[0][0]']
#
#  activation_20 (Activation)     (None, 64, 64, 64)   0           ['add_20[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_20[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 64, 64, 64)  256         ['conv2d_44[0][0]']
#  ormalization)
#
#  conv2d_45 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 64, 64, 64)  256         ['conv2d_45[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_43[0][0]',
#                                                                   'activation_20[0][0]']
#
#  activation_21 (Activation)     (None, 64, 64, 64)   0           ['add_21[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_21[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 64, 64, 64)  256         ['conv2d_46[0][0]']
#  ormalization)
#
#  conv2d_47 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 64, 64, 64)  256         ['conv2d_47[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_45[0][0]',
#                                                                   'activation_21[0][0]']
#
#  activation_22 (Activation)     (None, 64, 64, 64)   0           ['add_22[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_22[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 64, 64, 64)  256         ['conv2d_48[0][0]']
#  ormalization)
#
#  conv2d_49 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 64, 64, 64)  256         ['conv2d_49[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_47[0][0]',
#                                                                   'activation_22[0][0]']
#
#  activation_23 (Activation)     (None, 64, 64, 64)   0           ['add_23[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_23[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 64, 64, 64)  256         ['conv2d_50[0][0]']
#  ormalization)
#
#  conv2d_51 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 64, 64, 64)  256         ['conv2d_51[0][0]']
#  ormalization)
#
#  add_24 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_49[0][0]',
#                                                                   'activation_23[0][0]']
#
#  activation_24 (Activation)     (None, 64, 64, 64)   0           ['add_24[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_24[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 64, 64, 64)  256         ['conv2d_52[0][0]']
#  ormalization)
#
#  conv2d_53 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_50[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 64, 64, 64)  256         ['conv2d_53[0][0]']
#  ormalization)
#
#  add_25 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_51[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_25 (Activation)     (None, 64, 64, 64)   0           ['add_25[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_25[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 64, 64, 64)  256         ['conv2d_54[0][0]']
#  ormalization)
#
#  conv2d_55 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 64, 64, 64)  256         ['conv2d_55[0][0]']
#  ormalization)
#
#  add_26 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_53[0][0]',
#                                                                   'activation_25[0][0]']
#
#  activation_26 (Activation)     (None, 64, 64, 64)   0           ['add_26[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_26[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 64, 64, 64)  256         ['conv2d_56[0][0]']
#  ormalization)
#
#  conv2d_57 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 64, 64, 64)  256         ['conv2d_57[0][0]']
#  ormalization)
#
#  add_27 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_55[0][0]',
#                                                                   'activation_26[0][0]']
#
#  activation_27 (Activation)     (None, 64, 64, 64)   0           ['add_27[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_27[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 64, 64, 64)  256         ['conv2d_58[0][0]']
#  ormalization)
#
#  conv2d_59 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_56[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 64, 64, 64)  256         ['conv2d_59[0][0]']
#  ormalization)
#
#  add_28 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_57[0][0]',
#                                                                   'activation_27[0][0]']
#
#  activation_28 (Activation)     (None, 64, 64, 64)   0           ['add_28[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_28[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 64, 64, 64)  256         ['conv2d_60[0][0]']
#  ormalization)
#
#  conv2d_61 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_58[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 64, 64, 64)  256         ['conv2d_61[0][0]']
#  ormalization)
#
#  add_29 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_59[0][0]',
#                                                                   'activation_28[0][0]']
#
#  activation_29 (Activation)     (None, 64, 64, 64)   0           ['add_29[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_29[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 64, 64, 64)  256         ['conv2d_62[0][0]']
#  ormalization)
#
#  conv2d_63 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_60[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 64, 64, 64)  256         ['conv2d_63[0][0]']
#  ormalization)
#
#  add_30 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_61[0][0]',
#                                                                   'activation_29[0][0]']
#
#  activation_30 (Activation)     (None, 64, 64, 64)   0           ['add_30[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_30[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 64, 64, 64)  256         ['conv2d_64[0][0]']
#  ormalization)
#
#  conv2d_65 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_62[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 64, 64, 64)  256         ['conv2d_65[0][0]']
#  ormalization)
#
#  add_31 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_63[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_31 (Activation)     (None, 64, 64, 64)   0           ['add_31[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_31[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 64, 64, 64)  256         ['conv2d_66[0][0]']
#  ormalization)
#
#  conv2d_67 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_64[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 64, 64, 64)  256         ['conv2d_67[0][0]']
#  ormalization)
#
#  add_32 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_65[0][0]',
#                                                                   'activation_31[0][0]']
#
#  activation_32 (Activation)     (None, 64, 64, 64)   0           ['add_32[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_32[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 64, 64, 64)  256         ['conv2d_68[0][0]']
#  ormalization)
#
#  conv2d_69 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_66[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 64, 64, 64)  256         ['conv2d_69[0][0]']
#  ormalization)
#
#  add_33 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_67[0][0]',
#                                                                   'activation_32[0][0]']
#
#  activation_33 (Activation)     (None, 64, 64, 64)   0           ['add_33[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 128, 128, 64  36928      ['activation_33[0][0]']
#  ose)                           )
#
#  conv2d_transpose_1 (Conv2DTran  (None, 256, 256, 64  36928      ['conv2d_transpose[0][0]']
#  spose)                         )
#
#  conv2d_70 (Conv2D)             (None, 256, 256, 1)  3137        ['conv2d_transpose_1[0][0]']
#
# ==================================================================================================
# Total params: 2,643,073
# Trainable params: 2,634,369
# Non-trainable params: 8,704
# __________________________________________________________________________________________________

# %% [markdown]
# # Training the model

# %%
model.fit(X_train,Y_train, validation_split=0.2, epochs=25)
# Out:
# Epoch 1/25
# 79/79 [==============================] - 106s 561ms/step - loss: 0.3196 - val_loss: 0.9985
# Epoch 2/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0977 - val_loss: 0.5214
# Epoch 3/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0777 - val_loss: 0.3939
# Epoch 4/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0639 - val_loss: 0.1578
# Epoch 5/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0632 - val_loss: 0.0792
# Epoch 6/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0594 - val_loss: 0.1025
# Epoch 7/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0665 - val_loss: 0.3020
# Epoch 8/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0554 - val_loss: 0.1141
# Epoch 9/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0495 - val_loss: 0.0978
# Epoch 10/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0524 - val_loss: 0.0496
# Epoch 11/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0516 - val_loss: 0.0504
# Epoch 12/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0509 - val_loss: 0.0464
# Epoch 13/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0448 - val_loss: 0.0414
# Epoch 14/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0499 - val_loss: 0.0797
# Epoch 15/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0445 - val_loss: 0.0462
# Epoch 16/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0439 - val_loss: 0.0617
# Epoch 17/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0471 - val_loss: 0.1199
# Epoch 18/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0478 - val_loss: 0.0766
# Epoch 19/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0421 - val_loss: 0.0586
# Epoch 20/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0421 - val_loss: 0.0453
# Epoch 21/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0467 - val_loss: 0.0397
# Epoch 22/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0420 - val_loss: 0.0655
# Epoch 23/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0479 - val_loss: 0.1308
# Epoch 24/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0439 - val_loss: 0.0547
# Epoch 25/25
# 79/79 [==============================] - 39s 495ms/step - loss: 0.0424 - val_loss: 0.0920

# %%
model.save_weights('model25.h5')

# %%
a = model.history.history['val_loss']
b = model.history.history['loss']
print(a)
print(b)
# Out:
# [0.9985066056251526, 0.5213621854782104, 0.39390361309051514, 0.15777525305747986, 0.07915116101503372, 0.1024715006351471, 0.301967978477478, 0.11413514614105225, 0.09777098149061203, 0.04964987561106682, 0.0503963828086853, 0.04640861973166466, 0.04135964438319206, 0.07967519760131836, 0.04618353396654129, 0.061723742634058, 0.11988164484500885, 0.0766148567199707, 0.05857740715146065, 0.04526172950863838, 0.03969277814030647, 0.06551457196474075, 0.1307910978794098, 0.05465428903698921, 0.09197985380887985]
# [0.3195965588092804, 0.09773796051740646, 0.07774664461612701, 0.0639001652598381, 0.063180111348629, 0.05941503122448921, 0.0665377527475357, 0.05535587668418884, 0.04949125647544861, 0.052389711141586304, 0.05155612900853157, 0.05085379630327225, 0.04483596980571747, 0.04991057142615318, 0.04445385932922363, 0.04387463629245758, 0.047068819403648376, 0.047843776643276215, 0.04213350638747215, 0.042079053819179535, 0.046697720885276794, 0.041968006640672684, 0.04785532504320145, 0.043886732310056686, 0.04239361360669136]

# %%
plt.plot(b , label="Training loss")
plt.plot(a , label="Validation loss")
plt.legend()
plt.show()

# %%
model.load_weights('model25.h5')

# %%
output_images = model.predict(X_test)
# Out:
# 25/25 [==============================] - 3s 114ms/step

# %% [markdown]
# # Post processing

# %% [markdown]
# **Finding the inverse mask**

# %%
# Finding the inverse of mask
inv_mask = np.ones((256,256))
inv_mask[112:144,:] = np.zeros((32,256))
plt.imshow(inv_mask,cmap='gray')

# %% [markdown]
# * Multiply the inverse to the kspace obtained from the output image of model
# * Add this obtained result to the undersampled kspace to get the fully sampled kspace
# * Inverse Fourier transform to convert data from frequency domain to image domain
#
# This is the final output of the algorithm

# %%
recon_kspaces = []
recon_images = []
for i in range(len(output_images)):
    r_kspace = np.array(citf(output_images[i]))
    r_kspace = np.multiply(r_kspace , inv_mask)
    r_kspace = r_kspace + citf(X_test[i])
    recon_kspaces.append(r_kspace)
    recon_images.append(cfti(r_kspace))
recon_kspaces = np.asarray(recon_kspaces)
recon_images = np.asarray(recon_images)

# %% [markdown]
# # Visualizing the output from the model after preprocessing

# %%
plt.subplot(131), plt.imshow(Y_test[2], cmap='gray')
plt.title('Ground Truth'), plt.xticks([]), plt.yticks([])
plt.subplot(132), plt.imshow(X_test[2], cmap='gray')
plt.title('Undersampled Image'), plt.xticks([]), plt.yticks([])
plt.subplot(133), plt.imshow(recon_images[2], cmap='gray')
plt.title('Reconstructed Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# # END OF PROJECT PHASE I
